# %%
import os

# %%
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"

# %%
from huggingface_hub import snapshot_download

# %%
collabllm_model_hf_ids = {
    "code": "collabllm/CollabLLM-code-Llama-3.1-8B-Instruct",
    "math": "collabllm/CollabLLM-math-Llama-3.1-8B-Instruct",
}

# %%
adapter_paths = {
    k: snapshot_download(repo_id=v)
    for k, v in collabllm_model_hf_ids.items()
}

# %%
adapter_paths
# Out:
# {'code': '/home/v-homatthew/.cache/huggingface/hub/models--collabllm--CollabLLM-code-Llama-3.1-8B-Instruct/snapshots/4de9e9b4061a520b40c34245b0b0f20a35c4197a',
#  'math': '/home/v-homatthew/.cache/huggingface/hub/models--collabllm--CollabLLM-math-Llama-3.1-8B-Instruct/snapshots/8f116f6e790a61b7701f1b25ebb86eb2f11e253d'}

# %%
print(adapter_paths["math"])
# Out:
# /home/v-homatthew/.cache/huggingface/hub/models--collabllm--CollabLLM-math-Llama-3.1-8B-Instruct/snapshots/8f116f6e790a61b7701f1b25ebb86eb2f11e253d

# %%
print(adapter_paths["code"])
# Out:
# /home/v-homatthew/.cache/huggingface/hub/models--collabllm--CollabLLM-code-Llama-3.1-8B-Instruct/snapshots/4de9e9b4061a520b40c34245b0b0f20a35c4197a
